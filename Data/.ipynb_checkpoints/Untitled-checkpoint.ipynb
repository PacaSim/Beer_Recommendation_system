# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('정제된데이터.csv', encoding='utf-8')

# %%
data
# Out:
#        Unnamed: 0.1  Unnamed: 0                  아이디                      맥주
# 0                 1           1   italianjohn(5,524)  Kloud Original Gravity  \
# 1                 3           3  Radek Kliber(8,125)  Kloud Original Gravity
# 2                 4           4    geologyguy(2,602)  Kloud Original Gravity
# 3                 7           7      pictoman(6,023)  Kloud Original Gravity
# 4                 8           8  snoworsummer(9,674)  Kloud Original Gravity
# ...             ...         ...                  ...                     ...
# 37642         69200        3817   bierkoning(19,560)                Heineken
# 37643         69201        3867      ClarkVV(11,541)                Heineken
# 37644         69202        4031       omhper(37,431)                Heineken
# 37645         69203        4132           Ron(7,165)                Heineken
# 37646         69204        4222        Oakes(28,942)                Heineken
#
# ...

# %%
beer_name = data['맥주'].unique()

# %%
beer_name
# Out:
# array(['Kloud Original Gravity', 'Kloud Fitz Super Clear',
#        'Asahi Super Dry', 'Tsingtao', 'Heineken', 'Kirin Ichiban',
#        'Sapporo Premium Beer / Draft Beer', 'Stella Artois',
#        'Guinness Draught', 'Kronenbourg 1664 Blanc', 'Pilsner Urquell',
#        'San Miguel', 'OB Premier Pilsner', 'Cass Fresh',
#        'Eichbaum Apostel Bräu', 'Egger Zwickl', 'Egger Märzenbier',
#        'Holsten Premium Bier', 'Bintang Pilsener', 'Krombacher Weizen',
#        'Miller Genuine Draft (MGD)', 'Tiger Radler Lemon',
#        "Suntory The Premium Malt's", 'Reeper B. Blondes Weissbier',
#        'Tiger Beer', 'Tsingtao Wheat Beer', 'Erdinger Weissbier',
#        'Carlsberg Pilsner', 'Budweiser', 'Sapporo Yebisu',
#        'Paulaner Hefe-Weissbier', 'Desperados', 'Peroni Nastro Azzurro',
#        'Edelweiss Weissbier Snowfresh', 'Heineken Dark Lager',
#        'Kozel Černý (Dark) 10°', 'Guinness Original 4.2% (Ireland/UK)',
# ...

# %%
beer_name = pd.Series(beer_name)

# %%
print(type(beer_name))
# Out:
# <class 'pandas.core.series.Series'>

# %%
beer_list =pd.DataFrame(beer_name)

# %%
beer_list
# Out:
#                                             0
# 0                      Kloud Original Gravity
# 1                      Kloud Fitz Super Clear
# 2                             Asahi Super Dry
# 3                                    Tsingtao
# 4                                    Heineken
# ..                                        ...
# 57      Volfas Engelman Grünberger Hefeweizen
# 58  Berliner Kindl Jubiläums Pilsener Premium
# 59                                   Red Rock
# 60                  Erdinger Weissbier Dunkel
# 61                   Warsteiner Premium Verum
#
# [62 rows x 1 columns]

# %%
beer_list.to_csv('beer_list.csv', encoding="utf-8")
